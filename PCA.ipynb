# %%
import numpy as np
import pandas as pd

all_data = pd.read_csv('voice.csv')
features = [feat for feat in all_data.columns if feat != 'label']
output = 'label'
all_data[output].replace(['male','female'], [1, 0], inplace = True)
all_samples = all_data[features].values
labels = all_data[output].values
all_samples = all_samples.T
#print(all_samples.shape)

# %%
mean_vector = np.zeros((20,1))
for i in range(20):
    mean = np.mean(all_samples[i,:])
    mean_vector[i] += mean

print('Mean vector:\n', mean_vector)
# Out:
# Mean vector:
#  [[  0.18090661]
#  [  0.05712596]
#  [  0.18562068]
#  [  0.14045559]
#  [  0.22476496]
#  [  0.08430937]
#  [  3.14016752]
#  [ 36.56846079]
#  [  0.89512706]
#  [  0.40821641]
#  [  0.1652818 ]
#  [  0.18090661]
#  [  0.14280673]
#  [  0.03680181]
#  [  0.25884225]
#  [  0.82921096]
#  [  0.05264705]
#  [  5.04727674]
#  [  4.99462969]
#  [  0.17375151]]

# %%
scatter_matrix = np.zeros((20,20))
#print(len(all_samples[:,i].T))
#print(all_samples.shape[0])
for i in range(all_samples.shape[1]):
    scatter_matrix += (all_samples[:,i].T - mean_vector).dot((all_samples[:,i].T - mean_vector).T)
#print('Scatter Matrix:\n', scatter_matrix)

# %%
#cov_mat = np.cov([all_samples[0,:],all_samples[1,:], all_samples[2,:]])
#print('Covariance Matrix:\n', cov_mat)

# %%
eig_val_sc, eig_vec_sc = np.linalg.eig(scatter_matrix)

# eigenvectors and eigenvalues for the from the covariance matrix
#eig_val_cov, eig_vec_cov = np.linalg.eig(cov_mat)

for i in range(len(eig_val_sc)):
    eigvec_sc = eig_vec_sc[:,i].reshape(1,20).T
    #eigvec_cov = eig_vec_cov[:,i].reshape(1,20).T
    #assert eigvec_sc.all() == eigvec_cov.all(), 'Eigenvectors are not identical'

    print('Eigenvector {}: \n{}'.format(i+1, eigvec_sc))
    print('Eigenvalue {} from scatter matrix: {}'.format(i+1, eig_val_sc[i]))
    #print('Eigenvalue {} from covariance matrix: {}'.format(i+1, eig_val_cov[i]))
    #print('Scaling factor: ', eig_val_sc[i]/eig_val_cov[i])
    print(40 * '-')
# Out:
# Eigenvector 1:
# [[-0.2236068]
#  [-0.2236068]
#  [-0.2236068]
#  [-0.2236068]
#  [-0.2236068]
#  [-0.2236068]
#  [-0.2236068]
#  [-0.2236068]
#  [-0.2236068]
#  [-0.2236068]
#  [-0.2236068]
#  [-0.2236068]
#  [-0.2236068]
#  [-0.2236068]
#  [-0.2236068]
#  [-0.2236068]
#  [-0.2236068]
#  [-0.2236068]
#  [-0.2236068]
#  [-0.2236068]]
# Eigenvalue 1 from scatter matrix: 1235397828.9595625
# ----------------------------------------
# Eigenvector 2:
# [[ 0.07078099]
#  [ 0.07427509]
#  [ 0.07064792]
#  [ 0.07192284]
#  [ 0.06954294]
#  [ 0.07350775]
#  [-0.01275355]
#  [-0.95637321]
#  [ 0.05061985]
#  [ 0.06436444]
#  [ 0.07122205]
#  [ 0.07078099]
#  [ 0.07185648]
#  [ 0.0748488 ]
#  [ 0.068581  ]
#  [ 0.05248054]
#  [ 0.07440152]
#  [-0.06658776]
#  [-0.06510163]
#  [ 0.07098296]]
# Eigenvalue 2 from scatter matrix: 79515099.53440629
# ----------------------------------------
# Eigenvector 3:
# [[-0.18531639]
#  [-0.04413063]
#  [ 0.25409659]
#  [ 0.21638866]
#  [ 0.08350985]
#  [-0.1372096 ]
#  [-0.21926744]
#  [-0.12595531]
#  [ 0.20525901]
#  [ 0.2748705 ]]
# Eigenvalue 13 from scatter matrix: -1.8120953920528832e-07
# ----------------------------------------
# Eigenvector 14:
# [[ 0.09146438]
#  [-0.51786375]
#  [ 0.05343359]
#  [ 0.16845235]
#  [-0.03943223]
#  [-0.07624395]
#  [-0.29558386]
#  [ 0.01814142]
#  [-0.11119786]
#  [ 0.4073577 ]
#  [-0.17867561]
#  [ 0.1120359 ]
#  [ 0.35995746]
#  [-0.15595368]
#  [-0.19810697]
#  [ 0.27738031]
#  [ 0.22495764]
#  [-0.13111902]
#  [ 0.13050737]
#  [-0.13951121]]
# Eigenvalue 14 from scatter matrix: -1.2934855739089137e-07
# ----------------------------------------
# Eigenvector 15:
# [[ 0.03693127]
#  [-0.16979405]
#  [-0.51375038]
#  [ 0.1097107 ]
#  [ 0.16136172]
#  [ 0.05034892]
#  [-0.0941803 ]
#  [-0.02530762]
#  [ 0.17321443]
#  [-0.16138346]
#  [ 0.16233986]
#  [ 0.06725629]
#  [-0.13782911]
#  [-0.40160325]
#  [ 0.03467884]
#  [-0.23995648]
#  [ 0.44969806]
#  [ 0.26262551]
#  [-0.00626612]
#  [ 0.24190516]]
# Eigenvalue 15 from scatter matrix: -3.424548577471856e-08
# ----------------------------------------
# Eigenvector 16:
# [[-0.66606292]
#  [-0.12926301]
#  [-0.13017265]
#  [ 0.07820828]
#  [ 0.04020943]
#  [-0.01247391]
#  [ 0.00237352]
#  [-0.00670771]
#  [-0.02399372]
#  [ 0.05584166]
#  [ 0.01086309]
#  [ 0.68711813]
#  [ 0.06687609]
#  [-0.08392528]
#  [-0.03847995]
#  [ 0.01416952]
#  [ 0.10288736]
#  [-0.05923747]
#  [ 0.10638437]
#  [-0.01461483]]
# Eigenvalue 16 from scatter matrix: 1.4740649666042747e-08
# ----------------------------------------
# Eigenvector 17:
# [[ 0.07527984]
#  [-0.1757234 ]
#  [-0.28469804]
#  [-0.11392115]
#  [-0.48641407]
#  [-0.37686598]
#  [-0.05763833]
#  [ 0.01047896]
#  [ 0.11435914]
#  [-0.10775547]
#  [ 0.11829723]
#  [ 0.06974043]
#  [ 0.19650454]
#  [ 0.43894144]
#  [ 0.32105795]
#  [ 0.16122066]
#  [ 0.09389125]
#  [ 0.14394911]
#  [-0.21872278]
#  [ 0.07801867]]
# Eigenvalue 17 from scatter matrix: 3.858604117262074e-07
# ----------------------------------------
# Eigenvector 18:
# [[-0.01858156]
#  [ 0.02093595]
#  [ 0.01532077]
#  [ 0.32398845]
#  [-0.42259708]
#  [ 0.15610128]
#  [ 0.09657286]
#  [ 0.02306864]
#  [ 0.15521519]
#  [-0.57481169]
#  [ 0.25678069]
#  [-0.01697613]
#  [ 0.20949994]
#  [ 0.18117323]
#  [-0.36249993]
#  [ 0.10247755]
#  [ 0.0849495 ]
#  [-0.18257707]
#  [-0.03260782]
#  [-0.01543276]]
# Eigenvalue 18 from scatter matrix: 3.1887836891012464e-07
# ----------------------------------------
# Eigenvector 19:
# [[ 0.06045399]
#  [ 0.27776336]
#  [-0.35536957]
#  [ 0.03184024]
#  [-0.23002762]
#  [-0.04691556]
#  [-0.11695989]
#  [-0.00307894]
#  [-0.15220433]
#  [ 0.20383354]
#  [ 0.39903151]
#  [ 0.05244003]
#  [-0.00434557]
#  [ 0.23711768]
#  [-0.29835108]
#  [-0.22024801]
#  [-0.12023092]
#  [-0.28036237]
#  [ 0.44030941]
#  [ 0.1253041 ]]
# Eigenvalue 19 from scatter matrix: 2.2052752452424404e-07
# ----------------------------------------
# Eigenvector 20:
# [[ 0.02124684]
#  [ 0.15561667]
#  [ 0.20621448]
#  [ 0.13536316]
#  [-0.08522363]
#  [-0.36830748]
#  [ 0.19168591]
#  [ 0.04986916]
#  [-0.44233509]
#  [ 0.13146263]
#  [ 0.33374527]
#  [ 0.0173604 ]
#  [-0.23341259]
#  [-0.06990749]
#  [-0.20247592]
#  [ 0.01381202]
#  [ 0.45061802]
#  [-0.20562304]
#  [-0.21844636]
#  [ 0.11873704]]
# Eigenvalue 20 from scatter matrix: 1.730274177245567e-07
# ----------------------------------------

# %%
#for item in eig_vec_sc:
   # np.testing.assert_array_almost_equal(1.0, np.linalg.norm(item))

# %%
eig_pairs = [[np.real(eig_val_sc[i]),eig_vec_sc[:,i]] for i in range(len(eig_val_sc))]

eig_pairs.sort(key = lambda x: x[0], reverse = True)
#eig_pairs.real

#for j in range(20):
    #eig_pairs[j][1] = eig_pairs[j][1].real
    #print(eig_pairs[0][1].real)
for i in eig_pairs:
    print(i[0])

#print(len(eig_pairs[0][1]))
# Out:
# 1235397828.9595625
# 79515099.53440629
# 9.664112320492072e-07
# 7.809629583537764e-07
# 5.693062675719105e-07
# 5.088868199374355e-07
# 3.858604117262074e-07
# 3.1887836891012464e-07
# 2.2052752452424404e-07
# 1.730274177245567e-07
# 1.4740649666042747e-08
# -3.424548577471856e-08
# -1.2934855739089137e-07
# -1.8120953920528832e-07
# -3.2017664613850837e-07
# -3.5549787323355783e-07
# -4.600304503444154e-07
# -6.218723123567269e-07
# -7.130270906593734e-07
# -7.663873425660817e-07

# %%
#matrix_w = np.zeros((10,3168))
#print(matrix_w)
matrix_w = np.hstack((eig_pairs[0][1].reshape(20,1), eig_pairs[1][1].reshape(20,1)))
for i in range(2,10):
    matrix_w = np.hstack((matrix_w, eig_pairs[i][1].reshape(20,1)))
print("Matrix W:\n", matrix_w)
# Out:
# Matrix W:
#  [[-0.2236068   0.07078099 -0.18531639  0.3038605   0.02669513 -0.14470454
#    0.07527984 -0.01858156  0.06045399  0.02124684]
#  [-0.2236068   0.07427509 -0.04413063  0.22955252  0.29270921  0.09734729
#   -0.1757234   0.02093595  0.27776336  0.15561667]
#  [-0.2236068   0.07064792  0.25409659 -0.09757689 -0.20594793 -0.06336594
#   -0.28469804  0.01532077 -0.35536957  0.20621448]
#  [-0.2236068   0.07192284  0.21638866 -0.28524072 -0.09440766  0.26265571
#   -0.11392115  0.32398845  0.03184024  0.13536316]
#  [-0.2236068   0.06954294  0.08350985  0.18617986 -0.1082577   0.44946204
#   -0.48641407 -0.42259708 -0.23002762 -0.08522363]
#  [-0.2236068   0.07350775 -0.17312286 -0.13102782  0.17829481 -0.45842036
#   -0.37686598  0.15610128 -0.04691556 -0.36830748]
#  [-0.2236068  -0.01275355 -0.2418362   0.19894332 -0.08093492  0.01382096
#   -0.05763833  0.09657286 -0.11695989  0.19168591]
#  [-0.2236068  -0.95637321  0.00316823 -0.04814777  0.07164638 -0.04141889
#    0.01047896  0.02306864 -0.00307894  0.04986916]
#  [-0.2236068   0.05061985 -0.13845365 -0.31691777 -0.31649562  0.29309482
#    0.11435914  0.15521519 -0.15220433 -0.44233509]
#  [-0.2236068   0.06436444 -0.15838608 -0.32792307 -0.03693928 -0.02290619
#   -0.10775547 -0.57481169  0.20383354  0.13146263]
#  [-0.2236068   0.07122205 -0.34627129 -0.16925617 -0.13774879  0.01341574
#    0.11829723  0.25678069  0.39903151  0.33374527]
#  [-0.2236068   0.07078099 -0.17966156  0.29209322  0.0254714  -0.13625339
#    0.06974043 -0.01697613  0.05244003  0.0173604 ]
#  [-0.2236068   0.07185648  0.22671794  0.21303078  0.44771684 -0.34640712
#    0.19650454  0.20949994 -0.00434557 -0.23341259]
#  [-0.2236068   0.0748488   0.28841835  0.03093228 -0.32507233  0.22273757
#    0.43894144  0.18117323  0.23711768 -0.06990749]
#  [-0.2236068   0.068581    0.05874574 -0.06128144  0.50182066 -0.27094463
#    0.32105795 -0.36249993 -0.29835108 -0.20247592]
#  [-0.2236068   0.05248054 -0.45733757 -0.11537744  0.08625823  0.18552012
#    0.16122066  0.10247755 -0.22024801  0.01381202]
#  [-0.2236068   0.07440152  0.18287872  0.19745597  0.11365398 -0.05841844
#    0.09389125  0.0849495  -0.12023092  0.45061802]
#  [-0.2236068  -0.06658776  0.06144199  0.08437017 -0.27758732  0.0280073
#    0.14394911 -0.18257707 -0.28036237 -0.20562304]
#  [-0.2236068  -0.06510163  0.1622235   0.24136622 -0.17433163  0.20682584
#   -0.21872278 -0.03260782  0.44030941 -0.21844636]
#  [-0.2236068   0.07098296  0.38692667 -0.42503577  0.01345655 -0.23004788
#    0.07801867 -0.01543276  0.1253041   0.11873704]]

# %%
transformed = matrix_w.T.dot(all_samples)
#print(transformed.shape)
assert transformed.shape == (10,3168), "The matrix is not 10x3168 dimensional."
#print(transformed)
transformed = transformed.T

# %%
#Sigmoid funciont

def nonlin(x, deriv = False):
    if (deriv == True):
       return x * (1 - x)
    else:
       return 1/(1 + np.exp(-x))

# %%
#Split dataset into training dat and test data

#all_data = pd.read_csv('voice.csv')
features = [feat for feat in all_data.columns if feat != 'label']
output = 'label'
num_datapoints = len(transformed)

#Training data is first 90% of male and female
#Test data is las 10% of male and female

test_male = int(1584 * 0.1)
test_female = int((num_datapoints-1584) * 0.1)

#all_data[output].replace(['male','female'], [1, 0], inplace = True)

train_data_male = transformed[0:(1583-test_male)]
train_data_female = transformed[1584:-test_female]
test_data_male = transformed[(1583 - test_male):1583]
test_data_female = transformed[-test_female:]

train_data = np.concatenate((train_data_male, train_data_female), axis = 0)
test_data = np.concatenate((test_data_male, test_data_female),axis = 0)

train_labels_male = all_data[output].iloc[0:(1583 - test_male)].values
train_labels_female = all_data[output].iloc[1584:-test_female].values
test_labels_male = all_data[output].iloc[(1583 - test_male):1583].values 
test_labels_female = all_data[output].iloc[-test_female:].values

train_labels = np.concatenate((train_labels_male, train_labels_female), axis = 0)
test_labels = np.concatenate((test_labels_male, test_labels_female), axis = 0)

print(len(train_data))
print(len(test_data))
# Out:
# 2851
# 316

# %%
#To ensure random number of every loop is the same
np.random.seed(10)
#Initialize weights
syn0 = 2 * np.random.random((10,1)) - 1
l0 = train_data
#Keep updating weights
for iter in range(1000000):
    #l0 = train_data
    #Input(l0) with weights(syn0) 
    #Combined by sigmoid function
    l1 = nonlin(np.dot(l0,syn0))
    
    #How different that l1 from exact labels
    l1_error = train_labels.T - l1.T
    
    #l1_delta = l1_error.T * nonlin(l1, True)
    #syn0 += np.dot(l0.T, l1_delta)
    syn0 += np.dot(l0.T, l1_error.T)
print(l1)
# Out:
# [[ 1.]
#  [ 1.]
#  [ 1.]
#  ...,
#  [ 0.]
#  [ 0.]
#  [ 0.]]

# %%
count_0 = 0
count_1 = 0
for i in l1:
    if 0 in i:
       count_0 += 1
    else:
       count_1 += 1
print("predicted number of female", count_0)
print("predicted number of male", count_1)
print("total number of train data:",count_0 + count_1)
# Out:
# predicted number of female 1839
# predicted number of male 1012
# total number of train data: 2851

# %%
correct_predic = 0
wrong_predic = 0
for i in range(0,2851):
    if train_labels[i] == l1[i]:
       correct_predic += 1
    else:
       wrong_predic += 1
    
print("Number of correct prediction", correct_predic)
print("Number of wrong prediction", wrong_predic)
# Out:
# Number of correct prediction 2257
# Number of wrong prediction 594

# %%
print("Correct rate is: ")
print(correct_predic/(wrong_predic+correct_predic))
# Out:
# Correct rate is:
# 0.7916520519116099

# %%
l0 = test_data
   
l1 = nonlin(np.dot(l0,syn0))

# %%
count_0 = 0
count_1 = 0
for i in l1:
    if 0 in i:
       count_0 += 1
    else:
       count_1 += 1
print("predicted number of female", count_0)
print("predicted number of male", count_1)
print("total number of train data:",count_0 + count_1)
# Out:
# predicted number of female 250
# predicted number of male 66
# total number of train data: 316

# %%
correct_predic = 0
wrong_predic = 0
for i in range(0,316):
    if test_labels[i] == l1[i]:
       correct_predic += 1
    else:
       wrong_predic += 1
    
print("Number of correct prediction", correct_predic)
print("Number of wrong prediction", wrong_predic)
# Out:
# Number of correct prediction 217
# Number of wrong prediction 99

# %%
print("Correct rate is: ", correct_predic/(wrong_predic + correct_predic))
# Out:
# Correct rate is:  0.6867088607594937
